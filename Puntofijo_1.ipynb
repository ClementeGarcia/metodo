# %% [markdown]
# <a href="https://colab.research.google.com/github/ClementeGarcia/metodo/blob/main/Puntofijo_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from math import *
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
  return x**3 + 4*x**2 - 10.0

def g(x):
  return ((10-x**3)/4)**(1/2)

# %%
p0 = float(input("Ingrese el valor inicial p0:"))
tol = float(input("Ingrese el error: "))
N = int(input("Ingrese el número de iteraciones: "))
i = 1

while i <= N:
      p =g(p0)
      if abs(p - p0) < tol:
          print("El punto fijo es ",p,"despues de ",i,"iteraciones")
          break
      i = i + 1
      p0 = p 
      print("Iteración: ", p0) 

if i >= N:
    print("El método no converge") 

x = np.linspace(1,2,101) 
plt.plot(x,g(x))
plt.plot(x,f(x))
plt.title('punto fijo')
plt.grid()
plt.show()
# Out:
# Ingrese el valor inicial p0:1.5
# Ingrese el error: 0.00001
# Ingrese el número de iteraciones: 100
# Iteración:  1.286953767623375
# Iteración:  1.4025408035395783
# Iteración:  1.3454583740232942
# Iteración:  1.3751702528160383
# Iteración:  1.360094192761733
# Iteración:  1.3678469675921328
# Iteración:  1.3638870038840212
# Iteración:  1.36591673339004
# Iteración:  1.364878217193677
# Iteración:  1.365410061169957
# Iteración:  1.3651378206692129
# Iteración:  1.3652772085244786
# Iteración:  1.3652058502970472
# Iteración:  1.3652423837188388
# Iteración:  1.3652236802252822
# El punto fijo es  1.3652332557424998 despues de  16 iteraciones
